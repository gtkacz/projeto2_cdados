# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
treino=pd.read_csv("poker-hand-training-true.data",header=None)
teste=pd.read_csv("poker-hand-testing.data",header=None)
coluna=['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)','Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)','Mão']
treino.columns=coluna
teste.columns=coluna

treino.head()
# Out:
#    Naipe carta (1)  Valor carta (1)  Naipe carta (2)  Valor carta (2)  \
# 0                1               10                1               11
# 1                2               11                2               13
# 2                3               12                3               11
# 3                4               10                4               11
# 4                4                1                4               13
#
#    Naipe carta (3)  Valor carta (3)  Naipe carta (4)  Valor carta (4)  \
# 0                1               13                1               12
# 1                2               10                2               12
# 2                3               13                3               10
# 3                4                1                4               13
# 4                4               12                4               11
#
#    Naipe carta (5)  Valor carta (5)  Mão
# 0                1                1    9
# 1                2                1    9
# 2                3                1    9
# 3                4               12    9
# 4                4               10    9

# %%
t0=treino.loc[treino['Mão']==0, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t1=treino.loc[treino['Mão']==1, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t2=treino.loc[treino['Mão']==2, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t3=treino.loc[treino['Mão']==3, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t4=treino.loc[treino['Mão']==4, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t5=treino.loc[treino['Mão']==5, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t6=treino.loc[treino['Mão']==6, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t7=treino.loc[treino['Mão']==7, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t8=treino.loc[treino['Mão']==8, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

t9=treino.loc[treino['Mão']==9, ['Naipe carta (1)','Valor carta (1)','Naipe carta (2)','Valor carta (2)','Naipe carta (3)',
 'Valor carta (3)','Naipe carta (4)','Valor carta (4)','Naipe carta (5)','Valor carta (5)']]

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t0.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t1.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t2.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t3.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t4.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t5.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t6.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t7.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t8.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(t9.corr(), annot = True, cmap="YlGnBu")
plt.show()
